# %% [markdown]
# <a href="https://colab.research.google.com/github/ernestoaguaysol/ernestoaguaysol.github.io/blob/main/mae_mse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
y_ejemplo = [115, 150, 210, 280]
y_pred_1 = [115, 149, 203, 280]
y_pred_2 = [110, 150, 279, 280]

# %%
mean_absolute_error(y_ejemplo, y_pred_1), mean_absolute_error(y_ejemplo, y_pred_2)
# Out:
# (2.0, 18.5)
